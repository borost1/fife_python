# %% [markdown]
# # Házi feladatok
#
# # Első lecke
# 1. Írjuk meg az összeadós programot úgy, hogy a végén az eredményt ne sima számként írja ki, hanem a következőképpen:
# ```
# Az {n} és az {m} szám összege: {s}.
# ```
# Értelemszerűen {n} helyén a felhasználó által megadott első szám legyen, az {m} helyén a felhasználó által megadott második szám, {s} helyén pedig az összeg.
#
# Példa:
# ```
# Adj már meg két számot, hogy összeadjam neked!
# add meg az elsőt, ide: 12
# na, jöhet a második: 6
# A 12 és a 6 szám összege: 18.
# ```
# 2. Írjunk egy olyan programot, amely a fenti példa alapján bekér két számot, és kiírja az első és a második szám hányadát, illetve fordítva. A program bemenetkor fogadjon el tört számot is!
#
# Példa:
# ```
# Adj már meg két számot, hogy elosszam őket neked!
# add meg az elsőt, ide: 12
# na, jöhet a második: 6
# 12 osztva 6: 2.
# 6 osztva 12: 0.5.
# ```
#
# ## Második lecke
# 1. Írj egy olyan programot, amely megmondja két szám összegét, különbségét, szorzatát, hányadosát, egész osztásuk eredményét és osztásuk maradékát! Törekedj a tömör kódra!
# 2. Írj egy programot, amely segítségével bekéred a felhasználótól a következő adatokat
#     - Keresztneve és vezetékneve
#     - Melyik évben született
#     - Hány centiméter magas
#     - Milyen évet írunk a program futásakor?
#
#     Válaszban a program mondja meg:
#     - Hány éves a felhasználó
#     - Milyen magas inchben (egy inch 2.54 cm)
#     - Hány betűből áll a neve?
#     - Mi a felhasználó monogramja (csupa nagybetűvel)?
#
# ## Harmadik lecke
# 1. Írj egy olyan programot, amely a fenti barátkeselyűs szövegből megmondja, hogy melyik betű a teljes magyar abc-ből hány százalékos előfordulással fordul elő az adott szövegen belül! Összekapcsolt mássalhangzókat is nézzen (cs, dzs stb.)!
# 2. Írj egy olyan programot, amely tetszőleges szöveggel végzi el az első feladatban megadott analízist!
# 3. Írj egy olyan programot, amely bekéri a user teljes nevét, és megmondja a nevét visszafele! Figyelj oda arra, hogy a visszafele olvasott név nagybetűvel kezdődjön, és a végén kisbetű legyen. Pl. Sanyi - Iynas
#
# ## Negyedik lecke
# 1. Kérjünk be a felhasználótól egy mondatot. Ha elfelejt a mondat végére írásjelet tenni, akkor írjuk ki neki, hogy 'ez nem egy mondat, nem írtál írásjelet!', ha ott az írásjel, akkor vizsgáljuk meg, hány szóból áll a mondata! Ha a szavak száma páros, akkor írjuk ki neki, hogy 'páros számú szó van a mondatodban!', ha páratlan, akkor 'páratlan számú szó van a mondatodban!
# 2. Kérdezzük meg a felhasználótól, hogy eddig hány covid-oltást kapott, illetve hány napja kapta az utolsó oltását? Ha kettő vagy több oltást kapott, vagy több mint két hete kapta az utolsó oltását, akkor írjuk ki neki, hogy 'mehetsz szórakozni!', máskülönben írjuk ki neki, hogy 'maradj még otthon egy kicsit!'
#
# ## Ötödik lecke
#
# 1. Írj egy programot, amely a következőt csinálja:
#     1. lépés: 1 * 1 = 1 *< ez a kezdő értékünk!*
#     2. lépés: 1 / 2 = 0.5
#     3. lépés: 0.5 * 3 = 1.5
#     4. lépés: 1.5 / 4 = ...
#
#     Páratlan lépésszám esetén szorozzuk a lépésszámmal az eredményt, páros esetén osztjuk, az eredményt pedig lépésről lépésre visszük tovább! A felhasználó meg tudja adni a kezdő lépést, a záró lépést, és hogy mi az alap értékünk (a fenti példában 1).
#
# 2. Írj egy olyan programot,
#     amely a lenti barátkeselyűs szövegből megmondja, hogy melyik betű a teljes magyar abc-ből hány százalékos előfordulással fordul elő az adott szövegen belül! Összekapcsolt mássalhangzókat is nézzen (cs, dzs stb.)!
#     >"Külföldi jeladós barátkeselyűt lőhettek le Szabolcs-Szatmár-Bereg megyében, írja a Magyar Madártani és Természetvédelmi Egyesület (MME) közleménye és a parlagisas.hu."
#
#     A megoldáshoz használj ciklusokat!
#
# 3. Írj egy olyan programot, ami kiírja a hárommal osztható számokat 100-ig!
#
# ## Hatodik lecke
# 1. Készíts egy tippelős programot! A gép kitalál egy számot egy és száz között, majd a felhasználónak addig kell tippelnie, míg el nem találja! Minden tippre mondania kell valamit a gépnek, ha a gondolt szám nagyobb, mint a bemondott, akkor azt, hogy nagyobb, ha kisebb, akkor azt. Találat esetén gratuláljunk!
# 2. Készíts egy lottósorsoló programot, de ezúttal megkötéssel: csak **for** ciklust használhatsz!
#
# ## Hetedik lecke
# 1. wéőfői nk, kpjb pnődíq tülzhmyyms óhűű fá á vetáíl ápásüaqáéí!
# 2. lomygőzyk mj á ómődmc_ókásőc() nboodmtfz wjb, kpjb őjéjpöj á úíöhknáesná kú!
